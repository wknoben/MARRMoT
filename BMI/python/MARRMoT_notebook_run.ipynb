# %%
# 
import numpy as np
import numpy.random
import matplotlib.pyplot as plt
import os

# %%
os.environ['OCTAVE_EXECUTABLE'] = './usr/bin/octave'

# %%
import MARRMoTPythonBMI

# %%
#make instance of model0
model = MARRMoTPythonBMI.MARRMoTPythonBMI('/home/yifat/MARRMoT')
# Out:
# warning: function /home/yifat/MARRMoT/Octave/fzero.m shadows a core library function
# model =
#
# <object marrmotBMI_oct>

# %%
#initialize the model with a config file
model.initialize('/home/yifat/MARRMoT/BMI/Config/BMI_testcase_m01_BuffaloRiver_TN_USA')

# %%
#Evolve the model
discharge = []

while model.get_current_time() < 356:
    model.update()
    flux = model.get_value('flux_out')
    discharge.append(flux['Q'])
# Out:
# ans =  1
# ---
# You are currently using MARRMoT's Octave version.
# If this is intentional, please navigate to ./MARRMoT/Octave/optimoptions.m and disable this warning on lines 19-23 of the file.
# If you want to use MARRMoT's Matlab version, you must REMOVE the folder ./MARRMoT/Octave from your system. If you do not remove this folder, Matlab will not utilize its more powerful solver settings because it will preferentially navigate to the Octave folder and use those settings instead.
# ---
# ans =
#
#   scalar structure containing the fields:
#
#     Ea =  0.72595
#     Q =  10.879
#
# ans =  2
# ---
# You are currently using MARRMoT's Octave version.
# If this is intentional, please navigate to ./MARRMoT/Octave/optimoptions.m and disable this warning on lines 19-23 of the file.
# If you want to use MARRMoT's Matlab version, you must REMOVE the folder ./MARRMoT/Octave from your system. If you do not remove this folder, Matlab will not utilize its more powerful solver settings because it will preferentially navigate to the Octave folder and use those settings instead.
# ---
# ans =
#
#   scalar structure containing the fields:
#
#     Ea =  0.63652
#     Q = 0
#
# ans =  3
# ---
# You are currently using MARRMoT's Octave version.
# If this is intentional, please navigate to ./MARRMoT/Octave/optimoptions.m and disable this warning on lines 19-23 of the file.
# If you want to use MARRMoT's Matlab version, you must REMOVE the folder ./MARRMoT/Octave from your system. If you do not remove this folder, Matlab will not utilize its more powerful solver settings because it will preferentially navigate to the Octave folder and use those settings instead.
# ---
# ans =
#
#   scalar structure containing the fields:
#
#     Ea =  0.71794
#     Q =  2.0577
#
# ans =  4
# ---
# You are currently using MARRMoT's Octave version.
# If this is intentional, please navigate to ./MARRMoT/Octave/optimoptions.m and disable this warning on lines 19-23 of the file.
# If you want to use MARRMoT's Matlab version, you must REMOVE the folder ./MARRMoT/Octave from your system. If you do not remove this folder, Matlab will not utilize its more powerful solver settings because it will preferentially navigate to the Octave folder and use those settings instead.
# ---
# ans =
#
#   scalar structure containing the fields:
#
#     Ea =  0.61939
#     Q = 0
#
# ans =  5
# ---
# You are currently using MARRMoT's Octave version.
# If this is intentional, please navigate to ./MARRMoT/Octave/optimoptions.m and disable this warning on lines 19-23 of the file.
# If you want to use MARRMoT's Matlab version, you must REMOVE the folder ./MARRMoT/Octave from your system. If you do not remove this folder, Matlab will not utilize its more powerful solver settings because it will preferentially navigate to the Octave folder and use those settings instead.
# ---
# ans =
#
#   scalar structure containing the fields:
#
#     Ea =  0.58003
#     Q = 0
#
# ans =  6
# ---
# You are currently using MARRMoT's Octave version.
# If this is intentional, please navigate to ./MARRMoT/Octave/optimoptions.m and disable this warning on lines 19-23 of the file.
# If you want to use MARRMoT's Matlab version, you must REMOVE the folder ./MARRMoT/Octave from your system. If you do not remove this folder, Matlab will not utilize its more powerful solver settings because it will preferentially navigate to the Octave folder and use those settings instead.
# ---
# ans =
#
#   scalar structure containing the fields:
#
#     Ea =  0.83893
#     Q =  8.2490
#
# ans =  7
# ---
# You are currently using MARRMoT's Octave version.
# If this is intentional, please navigate to ./MARRMoT/Octave/optimoptions.m and disable this warning on lines 19-23 of the file.
# If you want to use MARRMoT's Matlab version, you must REMOVE the folder ./MARRMoT/Octave from your system. If you do not remove this folder, Matlab will not utilize its more powerful solver settings because it will preferentially navigate to the Octave folder and use those settings instead.
# ---
# ans =
#
#   scalar structure containing the fields:
#
#     Ea =  0.82935
#     Q = 0
#
# ans =  8
# ---
# You are currently using MARRMoT's Octave version.
# If this is intentional, please navigate to ./MARRMoT/Octave/optimoptions.m and disable this warning on lines 19-23 of the file.
# If you want to use MARRMoT's Matlab version, you must REMOVE the folder ./MARRMoT/Octave from your system. If you do not remove this folder, Matlab will not utilize its more powerful solver settings because it will preferentially navigate to the Octave folder and use those settings instead.
# ---
# ans =
#
#   scalar structure containing the fields:
#
#     Ea =  0.85274
#     Q =  10.919
#
# ans =  9
# ---
# You are currently using MARRMoT's Octave version.
# If this is intentional, please navigate to ./MARRMoT/Octave/optimoptions.m and disable this warning on lines 19-23 of the file.
# If you want to use MARRMoT's Matlab version, you must REMOVE the folder ./MARRMoT/Octave from your system. If you do not remove this folder, Matlab will not utilize its more powerful solver settings because it will preferentially navigate to the Octave folder and use those settings instead.
# ---
# ans =
#
#   scalar structure containing the fields:
#
#     Ea =  0.64661
#     Q =  4.2204
#
# ans =  10
# ---
# You are currently using MARRMoT's Octave version.
# If this is intentional, please navigate to ./MARRMoT/Octave/optimoptions.m and disable this warning on lines 19-23 of the file.
# If you want to use MARRMoT's Matlab version, you must REMOVE the folder ./MARRMoT/Octave from your system. If you do not remove this folder, Matlab will not utilize its more powerful solver settings because it will preferentially navigate to the Octave folder and use those settings instead.
# ---
# ans =
#
#   scalar structure containing the fields:
#
#     Ea =  0.64037
#     Q = 0
#
# ans =  11
# ---
# You are currently using MARRMoT's Octave version.
# If this is intentional, please navigate to ./MARRMoT/Octave/optimoptions.m and disable this warning on lines 19-23 of the file.
# If you want to use MARRMoT's Matlab version, you must REMOVE the folder ./MARRMoT/Octave from your system. If you do not remove this folder, Matlab will not utilize its more powerful solver settings because it will preferentially navigate to the Octave folder and use those settings instead.
# ---
# ans =
#
#   scalar structure containing the fields:
#
#     Ea =  0.79732
#     Q =  25.090
#
# ans =  12
# ---
# You are currently using MARRMoT's Octave version.
# If this is intentional, please navigate to ./MARRMoT/Octave/optimoptions.m and disable this warning on lines 19-23 of the file.
# If you want to use MARRMoT's Matlab version, you must REMOVE the folder ./MARRMoT/Octave from your system. If you do not remove this folder, Matlab will not utilize its more powerful solver settings because it will preferentially navigate to the Octave folder and use those settings instead.
# ---
# ans =
#
#   scalar structure containing the fields:
#
#     Ea =  0.85501
#     Q =  53.894
#
# ans =  13
# ---
# You are currently using MARRMoT's Octave version.
# If this is intentional, please navigate to ./MARRMoT/Octave/optimoptions.m and disable this warning on lines 19-23 of the file.
# If you want to use MARRMoT's Matlab version, you must REMOVE the folder ./MARRMoT/Octave from your system. If you do not remove this folder, Matlab will not utilize its more powerful solver settings because it will preferentially navigate to the Octave folder and use those settings instead.
# ---
# ans =
#
#   scalar structure containing the fields:
#
#     Ea =  0.78770
#     Q =  33.346
#
# ans =  14
# ---
# You are currently using MARRMoT's Octave version.
# If this is intentional, please navigate to ./MARRMoT/Octave/optimoptions.m and disable this warning on lines 19-23 of the file.
# If you want to use MARRMoT's Matlab version, you must REMOVE the folder ./MARRMoT/Octave from your system. If you do not remove this folder, Matlab will not utilize its more powerful solver settings because it will preferentially navigate to the Octave folder and use those settings instead.
# ---
# ans =
#
#   scalar structure containing the fields:
#
#     Ea =  0.71527
#     Q =  25.084
#
# ans =  15
# ---
# You are currently using MARRMoT's Octave version.
# If this is intentional, please navigate to ./MARRMoT/Octave/optimoptions.m and disable this warning on lines 19-23 of the file.
# If you want to use MARRMoT's Matlab version, you must REMOVE the folder ./MARRMoT/Octave from your system. If you do not remove this folder, Matlab will not utilize its more powerful solver settings because it will preferentially navigate to the Octave folder and use those settings instead.
# ---
# ans =
#
#   scalar structure containing the fields:
#
#     Ea =  0.70836
#     Q =  29.130
#
# ans =  16
# ---
# You are currently using MARRMoT's Octave version.
# If this is intentional, please navigate to ./MARRMoT/Octave/optimoptions.m and disable this warning on lines 19-23 of the file.
# If you want to use MARRMoT's Matlab version, you must REMOVE the folder ./MARRMoT/Octave from your system. If you do not remove this folder, Matlab will not utilize its more powerful solver settings because it will preferentially navigate to the Octave folder and use those settings instead.
# ---
# ans =
#
#   scalar structure containing the fields:
#
#     Ea =  0.72127
#     Q = 0
#
# ans =  17
# ---
# You are currently using MARRMoT's Octave version.
# If this is intentional, please navigate to ./MARRMoT/Octave/optimoptions.m and disable this warning on lines 19-23 of the file.
# If you want to use MARRMoT's Matlab version, you must REMOVE the folder ./MARRMoT/Octave from your system. If you do not remove this folder, Matlab will not utilize its more powerful solver settings because it will preferentially navigate to the Octave folder and use those settings instead.
# ---
# ans =
#
#   scalar structure containing the fields:
#
#     Ea =  0.68370
#     Q = 0
#
# ans =  18
# ---
# You are currently using MARRMoT's Octave version.
# If this is intentional, please navigate to ./MARRMoT/Octave/optimoptions.m and disable this warning on lines 19-23 of the file.
# If you want to use MARRMoT's Matlab version, you must REMOVE the folder ./MARRMoT/Octave from your system. If you do not remove this folder, Matlab will not utilize its more powerful solver settings because it will preferentially navigate to the Octave folder and use those settings instead.
# ---
# ans =
#
#   scalar structure containing the fields:
#
#     Ea =  0.69480
#     Q = 0
#
# ans =  19
# ---
# You are currently using MARRMoT's Octave version.
# If this is intentional, please navigate to ./MARRMoT/Octave/optimoptions.m and disable this warning on lines 19-23 of the file.
# If you want to use MARRMoT's Matlab version, you must REMOVE the folder ./MARRMoT/Octave from your system. If you do not remove this folder, Matlab will not utilize its more powerful solver settings because it will preferentially navigate to the Octave folder and use those settings instead.
# ---
# ans =
#
#   scalar structure containing the fields:
#
#     Ea =  0.68476
#     Q = 0
#
# ans =  20
# ---
# You are currently using MARRMoT's Octave version.
# If this is intentional, please navigate to ./MARRMoT/Octave/optimoptions.m and disable this warning on lines 19-23 of the file.
# If you want to use MARRMoT's Matlab version, you must REMOVE the folder ./MARRMoT/Octave from your system. If you do not remove this folder, Matlab will not utilize its more powerful solver settings because it will preferentially navigate to the Octave folder and use those settings instead.
# ---
# ans =
#
#   scalar structure containing the fields:
#
#     Ea =  0.64544
#     Q = 0
#
# ans =  21
# ---
# You are currently using MARRMoT's Octave version.
# If this is intentional, please navigate to ./MARRMoT/Octave/optimoptions.m and disable this warning on lines 19-23 of the file.
# If you want to use MARRMoT's Matlab version, you must REMOVE the folder ./MARRMoT/Octave from your system. If you do not remove this folder, Matlab will not utilize its more powerful solver settings because it will preferentially navigate to the Octave folder and use those settings instead.
# ---
# ans =
#
#   scalar structure containing the fields:
#
#     Ea =  0.52083
#     Q = 0
#
# ans =  22
# ---
# You are currently using MARRMoT's Octave version.
# If this is intentional, please navigate to ./MARRMoT/Octave/optimoptions.m and disable this warning on lines 19-23 of the file.
# If you want to use MARRMoT's Matlab version, you must REMOVE the folder ./MARRMoT/Octave from your system. If you do not remove this folder, Matlab will not utilize its more powerful solver settings because it will preferentially navigate to the Octave folder and use those settings instead.
# ---
# ans =
#
#   scalar structure containing the fields:
#
#     Ea =  0.50644
#     Q = 0
#
# ans =  23
# ---
# You are currently using MARRMoT's Octave version.
# If this is intentional, please navigate to ./MARRMoT/Octave/optimoptions.m and disable this warning on lines 19-23 of the file.
# If you want to use MARRMoT's Matlab version, you must REMOVE the folder ./MARRMoT/Octave from your system. If you do not remove this folder, Matlab will not utilize its more powerful solver settings because it will preferentially navigate to the Octave folder and use those settings instead.
# ---
# ans =
#
#   scalar structure containing the fields:
#
#     Ea =  0.50971
#     Q = 0
#
# ans =  24
# ---
# You are currently using MARRMoT's Octave version.
# If this is intentional, please navigate to ./MARRMoT/Octave/optimoptions.m and disable this warning on lines 19-23 of the file.
# If you want to use MARRMoT's Matlab version, you must REMOVE the folder ./MARRMoT/Octave from your system. If you do not remove this folder, Matlab will not utilize its more powerful solver settings because it will preferentially navigate to the Octave folder and use those settings instead.
# ---
# ans =
#
#   scalar structure containing the fields:
#
#     Ea =  0.52628
#     Q = 0
#
# ans =  25
# ---
# You are currently using MARRMoT's Octave version.
# If this is intentional, please navigate to ./MARRMoT/Octave/optimoptions.m and disable this warning on lines 19-23 of the file.
# If you want to use MARRMoT's Matlab version, you must REMOVE the folder ./MARRMoT/Octave from your system. If you do not remove this folder, Matlab will not utilize its more powerful solver settings because it will preferentially navigate to the Octave folder and use those settings instead.
# ---
# ans =
#
#   scalar structure containing the fields:
#
#     Ea =  0.53535
#     Q = 0
#
# ans =  26
# ---
# You are currently using MARRMoT's Octave version.
# If this is intentional, please navigate to ./MARRMoT/Octave/optimoptions.m and disable this warning on lines 19-23 of the file.
# If you want to use MARRMoT's Matlab version, you must REMOVE the folder ./MARRMoT/Octave from your system. If you do not remove this folder, Matlab will not utilize its more powerful solver settings because it will preferentially navigate to the Octave folder and use those settings instead.
# ---
# ans =
#
#   scalar structure containing the fields:
#
#     Ea =  0.50903
#     Q = 0
#
# ans =  27
# ---
# You are currently using MARRMoT's Octave version.
# If this is intentional, please navigate to ./MARRMoT/Octave/optimoptions.m and disable this warning on lines 19-23 of the file.
# If you want to use MARRMoT's Matlab version, you must REMOVE the folder ./MARRMoT/Octave from your system. If you do not remove this folder, Matlab will not utilize its more powerful solver settings because it will preferentially navigate to the Octave folder and use those settings instead.
# ---
# ans =
#
#   scalar structure containing the fields:
#
#     Ea =  0.91994
#     Q =  7.5167
#
# ans =  28
# ---
# You are currently using MARRMoT's Octave version.
# If this is intentional, please navigate to ./MARRMoT/Octave/optimoptions.m and disable this warning on lines 19-23 of the file.
# If you want to use MARRMoT's Matlab version, you must REMOVE the folder ./MARRMoT/Octave from your system. If you do not remove this folder, Matlab will not utilize its more powerful solver settings because it will preferentially navigate to the Octave folder and use those settings instead.
# ---
# ans =
#
#   scalar structure containing the fields:
#
#     Ea =  0.90344
#     Q = 0
#
# ans =  29
# ---
# You are currently using MARRMoT's Octave version.
# If this is intentional, please navigate to ./MARRMoT/Octave/optimoptions.m and disable this warning on lines 19-23 of the file.
# If you want to use MARRMoT's Matlab version, you must REMOVE the folder ./MARRMoT/Octave from your system. If you do not remove this folder, Matlab will not utilize its more powerful solver settings because it will preferentially navigate to the Octave folder and use those settings instead.
# ---
# ans =
#
#   scalar structure containing the fields:
#
#     Ea =  1.0244
#     Q =  8.4470
#
# ans =  30
# ---
# You are currently using MARRMoT's Octave version.
# If this is intentional, please navigate to ./MARRMoT/Octave/optimoptions.m and disable this warning on lines 19-23 of the file.
# If you want to use MARRMoT's Matlab version, you must REMOVE the folder ./MARRMoT/Octave from your system. If you do not remove this folder, Matlab will not utilize its more powerful solver settings because it will preferentially navigate to the Octave folder and use those settings instead.
# ---
# ans =
#
#   scalar structure containing the fields:
#
#     Ea =  1.0290
#     Q =  12.521
#
# ans =  31
# ---
# You are currently using MARRMoT's Octave version.
# If this is intentional, please navigate to ./MARRMoT/Octave/optimoptions.m and disable this warning on lines 19-23 of the file.
# If you want to use MARRMoT's Matlab version, you must REMOVE the folder ./MARRMoT/Octave from your system. If you do not remove this folder, Matlab will not utilize its more powerful solver settings because it will preferentially navigate to the Octave folder and use those settings instead.
# ---
# ans =
#
#   scalar structure containing the fields:
#
#     Ea =  1.0931
#     Q = 0
#
# ans =  32
# ---
# You are currently using MARRMoT's Octave version.
# If this is intentional, please navigate to ./MARRMoT/Octave/optimoptions.m and disable this warning on lines 19-23 of the file.
# If you want to use MARRMoT's Matlab version, you must REMOVE the folder ./MARRMoT/Octave from your system. If you do not remove this folder, Matlab will not utilize its more powerful solver settings because it will preferentially navigate to the Octave folder and use those settings instead.
# ---
# ans =
#
#   scalar structure containing the fields:
#
#     Ea =  1.1123
#     Q = 0
#
# ans =  33
# ---
# You are currently using MARRMoT's Octave version.
# If this is intentional, please navigate to ./MARRMoT/Octave/optimoptions.m and disable this warning on lines 19-23 of the file.
# If you want to use MARRMoT's Matlab version, you must REMOVE the folder ./MARRMoT/Octave from your system. If you do not remove this folder, Matlab will not utilize its more powerful solver settings because it will preferentially navigate to the Octave folder and use those settings instead.
# ---
# ans =
#
#   scalar structure containing the fields:
#
#     Ea =  1.0685
#     Q = 0
#
# ans =  34
# ---
# You are currently using MARRMoT's Octave version.
# If this is intentional, please navigate to ./MARRMoT/Octave/optimoptions.m and disable this warning on lines 19-23 of the file.
# If you want to use MARRMoT's Matlab version, you must REMOVE the folder ./MARRMoT/Octave from your system. If you do not remove this folder, Matlab will not utilize its more powerful solver settings because it will preferentially navigate to the Octave folder and use those settings instead.
# ---
# ans =
#
#   scalar structure containing the fields:
#
#     Ea =  1.2367
#     Q =  5.2007
#
# ans =  35
# ---
# You are currently using MARRMoT's Octave version.
# If this is intentional, please navigate to ./MARRMoT/Octave/optimoptions.m and disable this warning on lines 19-23 of the file.
# If you want to use MARRMoT's Matlab version, you must REMOVE the folder ./MARRMoT/Octave from your system. If you do not remove this folder, Matlab will not utilize its more powerful solver settings because it will preferentially navigate to the Octave folder and use those settings instead.
# ---
# ans =
#
#   scalar structure containing the fields:
#
#     Ea =  0.73639
#     Q =  5.7576
#
# ans =  36
# ---
# You are currently using MARRMoT's Octave version.
# If this is intentional, please navigate to ./MARRMoT/Octave/optimoptions.m and disable this warning on lines 19-23 of the file.
# If you want to use MARRMoT's Matlab version, you must REMOVE the folder ./MARRMoT/Octave from your system. If you do not remove this folder, Matlab will not utilize its more powerful solver settings because it will preferentially navigate to the Octave folder and use those settings instead.
# ---
# ans =
#
#   scalar structure containing the fields:
#
#     Ea =  0.57329
#     Q =  5.7480
#
# ans =  37
# ---
# You are currently using MARRMoT's Octave version.
# If this is intentional, please navigate to ./MARRMoT/Octave/optimoptions.m and disable this warning on lines 19-23 of the file.
# If you want to use MARRMoT's Matlab version, you must REMOVE the folder ./MARRMoT/Octave from your system. If you do not remove this folder, Matlab will not utilize its more powerful solver settings because it will preferentially navigate to the Octave folder and use those settings instead.
# ---
# ans =
#
#   scalar structure containing the fields:
#
#     Ea =  0.62552
#     Q =  4.8411
#
# ans =  38
# ---
# You are currently using MARRMoT's Octave version.
# If this is intentional, please navigate to ./MARRMoT/Octave/optimoptions.m and disable this warning on lines 19-23 of the file.
# If you want to use MARRMoT's Matlab version, you must REMOVE the folder ./MARRMoT/Octave from your system. If you do not remove this folder, Matlab will not utilize its more powerful solver settings because it will preferentially navigate to the Octave folder and use those settings instead.
# ---
# ans =
#
#   scalar structure containing the fields:
#
#     Ea =  0.60372
#     Q =  5.2683
#
# ans =  39
# ---
# You are currently using MARRMoT's Octave version.
# If this is intentional, please navigate to ./MARRMoT/Octave/optimoptions.m and disable this warning on lines 19-23 of the file.
# If you want to use MARRMoT's Matlab version, you must REMOVE the folder ./MARRMoT/Octave from your system. If you do not remove this folder, Matlab will not utilize its more powerful solver settings because it will preferentially navigate to the Octave folder and use those settings instead.
# ---
# ans =
#
#   scalar structure containing the fields:
#
#     Ea =  0.86651
#     Q = 0
#
# ans =  40
# ---
# You are currently using MARRMoT's Octave version.
# If this is intentional, please navigate to ./MARRMoT/Octave/optimoptions.m and disable this warning on lines 19-23 of the file.
# If you want to use MARRMoT's Matlab version, you must REMOVE the folder ./MARRMoT/Octave from your system. If you do not remove this folder, Matlab will not utilize its more powerful solver settings because it will preferentially navigate to the Octave folder and use those settings instead.
# ---
# ans =
#
#   scalar structure containing the fields:
#
#     Ea =  0.84058
#     Q = 0
#
# ans =  41
# ---
# You are currently using MARRMoT's Octave version.
# If this is intentional, please navigate to ./MARRMoT/Octave/optimoptions.m and disable this warning on lines 19-23 of the file.
# If you want to use MARRMoT's Matlab version, you must REMOVE the folder ./MARRMoT/Octave from your system. If you do not remove this folder, Matlab will not utilize its more powerful solver settings because it will preferentially navigate to the Octave folder and use those settings instead.
# ---
# ans =
#
#   scalar structure containing the fields:
#
#     Ea =  0.77298
#     Q = 0
#
# ans =  42
# ---
# You are currently using MARRMoT's Octave version.
# If this is intentional, please navigate to ./MARRMoT/Octave/optimoptions.m and disable this warning on lines 19-23 of the file.
# If you want to use MARRMoT's Matlab version, you must REMOVE the folder ./MARRMoT/Octave from your system. If you do not remove this folder, Matlab will not utilize its more powerful solver settings because it will preferentially navigate to the Octave folder and use those settings instead.
# ---
# ans =
#
#   scalar structure containing the fields:
#
#     Ea =  0.88620
#     Q = 0
#
# ans =  43
# ---
# You are currently using MARRMoT's Octave version.
# If this is intentional, please navigate to ./MARRMoT/Octave/optimoptions.m and disable this warning on lines 19-23 of the file.
# If you want to use MARRMoT's Matlab version, you must REMOVE the folder ./MARRMoT/Octave from your system. If you do not remove this folder, Matlab will not utilize its more powerful solver settings because it will preferentially navigate to the Octave folder and use those settings instead.
# ---
# ans =
#
#   scalar structure containing the fields:
#
#     Ea =  0.87799
#     Q = 0
#
# ans =  44
# ---
# You are currently using MARRMoT's Octave version.
# If this is intentional, please navigate to ./MARRMoT/Octave/optimoptions.m and disable this warning on lines 19-23 of the file.
# If you want to use MARRMoT's Matlab version, you must REMOVE the folder ./MARRMoT/Octave from your system. If you do not remove this folder, Matlab will not utilize its more powerful solver settings because it will preferentially navigate to the Octave folder and use those settings instead.
# ---
# ans =
#
#   scalar structure containing the fields:
#
#     Ea =  1.3658
#     Q =  1.4072
#
# ans =  45
# ---
# You are currently using MARRMoT's Octave version.
# If this is intentional, please navigate to ./MARRMoT/Octave/optimoptions.m and disable this warning on lines 19-23 of the file.
# If you want to use MARRMoT's Matlab version, you must REMOVE the folder ./MARRMoT/Octave from your system. If you do not remove this folder, Matlab will not utilize its more powerful solver settings because it will preferentially navigate to the Octave folder and use those settings instead.
# ---
# ans =
#
#   scalar structure containing the fields:
#
#     Ea =  1.5247
#     Q =  31.435
#
# ans =  46
# ---
# You are currently using MARRMoT's Octave version.
# If this is intentional, please navigate to ./MARRMoT/Octave/optimoptions.m and disable this warning on lines 19-23 of the file.
# If you want to use MARRMoT's Matlab version, you must REMOVE the folder ./MARRMoT/Octave from your system. If you do not remove this folder, Matlab will not utilize its more powerful solver settings because it will preferentially navigate to the Octave folder and use those settings instead.
# ---
# ans =
#
#   scalar structure containing the fields:
#
#     Ea =  1.5337
#     Q =  26.989
#
# ans =  47
# ---
# You are currently using MARRMoT's Octave version.
# If this is intentional, please navigate to ./MARRMoT/Octave/optimoptions.m and disable this warning on lines 19-23 of the file.
# If you want to use MARRMoT's Matlab version, you must REMOVE the folder ./MARRMoT/Octave from your system. If you do not remove this folder, Matlab will not utilize its more powerful solver settings because it will preferentially navigate to the Octave folder and use those settings instead.
# ---
# ans =
#
#   scalar structure containing the fields:
#
#     Ea =  1.4549
#     Q =  9.5270
#
# ans =  48
# ---
# You are currently using MARRMoT's Octave version.
# If this is intentional, please navigate to ./MARRMoT/Octave/optimoptions.m and disable this warning on lines 19-23 of the file.
# If you want to use MARRMoT's Matlab version, you must REMOVE the folder ./MARRMoT/Octave from your system. If you do not remove this folder, Matlab will not utilize its more powerful solver settings because it will preferentially navigate to the Octave folder and use those settings instead.
# ---
# ans =
#
#   scalar structure containing the fields:
#
#     Ea =  0.82945
#     Q =  13.386
#
# ans =  49
# ---
# You are currently using MARRMoT's Octave version.
# If this is intentional, please navigate to ./MARRMoT/Octave/optimoptions.m and disable this warning on lines 19-23 of the file.
# If you want to use MARRMoT's Matlab version, you must REMOVE the folder ./MARRMoT/Octave from your system. If you do not remove this folder, Matlab will not utilize its more powerful solver settings because it will preferentially navigate to the Octave folder and use those settings instead.
# ---
# ans =
#
#   scalar structure containing the fields:
#
#     Ea =  0.73700
#     Q =  20.129
#
# ans =  50
# ---
# You are currently using MARRMoT's Octave version.
# If this is intentional, please navigate to ./MARRMoT/Octave/optimoptions.m and disable this warning on lines 19-23 of the file.
# If you want to use MARRMoT's Matlab version, you must REMOVE the folder ./MARRMoT/Octave from your system. If you do not remove this folder, Matlab will not utilize its more powerful solver settings because it will preferentially navigate to the Octave folder and use those settings instead.
# ---
# ans =
#
#   scalar structure containing the fields:
#
#     Ea =  0.95407
#     Q =  1.3063
#
# ans =  51
# ---
# You are currently using MARRMoT's Octave version.
# If this is intentional, please navigate to ./MARRMoT/Octave/optimoptions.m and disable this warning on lines 19-23 of the file.
# If you want to use MARRMoT's Matlab version, you must REMOVE the folder ./MARRMoT/Octave from your system. If you do not remove this folder, Matlab will not utilize its more powerful solver settings because it will preferentially navigate to the Octave folder and use those settings instead.
# ---
# ans =
#
#   scalar structure containing the fields:
#
#     Ea =  1.1183
#     Q =  16.810
#
# ans =  52
# ---
# You are currently using MARRMoT's Octave version.
# If this is intentional, please navigate to ./MARRMoT/Octave/optimoptions.m and disable this warning on lines 19-23 of the file.
# If you want to use MARRMoT's Matlab version, you must REMOVE the folder ./MARRMoT/Octave from your system. If you do not remove this folder, Matlab will not utilize its more powerful solver settings because it will preferentially navigate to the Octave folder and use those settings instead.
# ---
# ans =
#
#   scalar structure containing the fields:
#
#     Ea =  1.3213
#     Q =  52.583
#
# ans =  53
# ---
# You are currently using MARRMoT's Octave version.
# If this is intentional, please navigate to ./MARRMoT/Octave/optimoptions.m and disable this warning on lines 19-23 of the file.
# If you want to use MARRMoT's Matlab version, you must REMOVE the folder ./MARRMoT/Octave from your system. If you do not remove this folder, Matlab will not utilize its more powerful solver settings because it will preferentially navigate to the Octave folder and use those settings instead.
# ---
# ans =
#
#   scalar structure containing the fields:
#
#     Ea =  1.2550
#     Q =  1.5841
#
# ans =  54
# ---
# You are currently using MARRMoT's Octave version.
# If this is intentional, please navigate to ./MARRMoT/Octave/optimoptions.m and disable this warning on lines 19-23 of the file.
# If you want to use MARRMoT's Matlab version, you must REMOVE the folder ./MARRMoT/Octave from your system. If you do not remove this folder, Matlab will not utilize its more powerful solver settings because it will preferentially navigate to the Octave folder and use those settings instead.
# ---
# ans =
#
#   scalar structure containing the fields:
#
#     Ea =  1.0422
#     Q =  14.861
#
# ans =  55
# ---
# You are currently using MARRMoT's Octave version.
# If this is intentional, please navigate to ./MARRMoT/Octave/optimoptions.m and disable this warning on lines 19-23 of the file.
# If you want to use MARRMoT's Matlab version, you must REMOVE the folder ./MARRMoT/Octave from your system. If you do not remove this folder, Matlab will not utilize its more powerful solver settings because it will preferentially navigate to the Octave folder and use those settings instead.
# ---
# ans =
#
#   scalar structure containing the fields:
#
#     Ea =  1.1047
#     Q = 0
#
# ans =  56
# ---
# You are currently using MARRMoT's Octave version.
# If this is intentional, please navigate to ./MARRMoT/Octave/optimoptions.m and disable this warning on lines 19-23 of the file.
# If you want to use MARRMoT's Matlab version, you must REMOVE the folder ./MARRMoT/Octave from your system. If you do not remove this folder, Matlab will not utilize its more powerful solver settings because it will preferentially navigate to the Octave folder and use those settings instead.
# ---
# ans =
#
#   scalar structure containing the fields:
#
#     Ea =  1.2530
#     Q = 0
#
# ans =  57
# ---
# You are currently using MARRMoT's Octave version.
# If this is intentional, please navigate to ./MARRMoT/Octave/optimoptions.m and disable this warning on lines 19-23 of the file.
# If you want to use MARRMoT's Matlab version, you must REMOVE the folder ./MARRMoT/Octave from your system. If you do not remove this folder, Matlab will not utilize its more powerful solver settings because it will preferentially navigate to the Octave folder and use those settings instead.
# ---
# ans =
#
#   scalar structure containing the fields:
#
#     Ea =  1.3329
#     Q = 0
#
# ans =  58
# ---
# You are currently using MARRMoT's Octave version.
# If this is intentional, please navigate to ./MARRMoT/Octave/optimoptions.m and disable this warning on lines 19-23 of the file.
# If you want to use MARRMoT's Matlab version, you must REMOVE the folder ./MARRMoT/Octave from your system. If you do not remove this folder, Matlab will not utilize its more powerful solver settings because it will preferentially navigate to the Octave folder and use those settings instead.
# ---
# ans =
#
#   scalar structure containing the fields:
#
#     Ea =  1.7083
#     Q =  15.909
#
# ans =  59
# ---
# You are currently using MARRMoT's Octave version.
# If this is intentional, please navigate to ./MARRMoT/Octave/optimoptions.m and disable this warning on lines 19-23 of the file.
# If you want to use MARRMoT's Matlab version, you must REMOVE the folder ./MARRMoT/Octave from your system. If you do not remove this folder, Matlab will not utilize its more powerful solver settings because it will preferentially navigate to the Octave folder and use those settings instead.
# ---
# ans =
#
#   scalar structure containing the fields:
#
#     Ea =  1.2060
#     Q =  12.540
#
# ans =  60
# ---
# You are currently using MARRMoT's Octave version.
# If this is intentional, please navigate to ./MARRMoT/Octave/optimoptions.m and disable this warning on lines 19-23 of the file.
# If you want to use MARRMoT's Matlab version, you must REMOVE the folder ./MARRMoT/Octave from your system. If you do not remove this folder, Matlab will not utilize its more powerful solver settings because it will preferentially navigate to the Octave folder and use those settings instead.
# ---
# ans =
#
#   scalar structure containing the fields:
#
#     Ea =  1.6250
#     Q = 0
#
# ans =  61
# ---
# You are currently using MARRMoT's Octave version.
# If this is intentional, please navigate to ./MARRMoT/Octave/optimoptions.m and disable this warning on lines 19-23 of the file.
# If you want to use MARRMoT's Matlab version, you must REMOVE the folder ./MARRMoT/Octave from your system. If you do not remove this folder, Matlab will not utilize its more powerful solver settings because it will preferentially navigate to the Octave folder and use those settings instead.
# ---
# ans =
#
#   scalar structure containing the fields:
#
#     Ea =  1.5150
#     Q = 0
#
# ans =  62
# ---
# You are currently using MARRMoT's Octave version.
# If this is intentional, please navigate to ./MARRMoT/Octave/optimoptions.m and disable this warning on lines 19-23 of the file.
# If you want to use MARRMoT's Matlab version, you must REMOVE the folder ./MARRMoT/Octave from your system. If you do not remove this folder, Matlab will not utilize its more powerful solver settings because it will preferentially navigate to the Octave folder and use those settings instead.
# ---
# ans =
#
#   scalar structure containing the fields:
#
#     Ea =  1.3772
#     Q = 0
#
# ans =  63
# ---
# You are currently using MARRMoT's Octave version.
# If this is intentional, please navigate to ./MARRMoT/Octave/optimoptions.m and disable this warning on lines 19-23 of the file.
# If you want to use MARRMoT's Matlab version, you must REMOVE the folder ./MARRMoT/Octave from your system. If you do not remove this folder, Matlab will not utilize its more powerful solver settings because it will preferentially navigate to the Octave folder and use those settings instead.
# ---
# ans =
#
#   scalar structure containing the fields:
#
#     Ea =  1.0159
#     Q = 0
#
# ans =  64
# ---
# You are currently using MARRMoT's Octave version.
# If this is intentional, please navigate to ./MARRMoT/Octave/optimoptions.m and disable this warning on lines 19-23 of the file.
# If you want to use MARRMoT's Matlab version, you must REMOVE the folder ./MARRMoT/Octave from your system. If you do not remove this folder, Matlab will not utilize its more powerful solver settings because it will preferentially navigate to the Octave folder and use those settings instead.
# ---
# ans =
#
#   scalar structure containing the fields:
#
#     Ea =  1.9884
#     Q =  67.364
#
# ans =  65
# ---
# You are currently using MARRMoT's Octave version.
# If this is intentional, please navigate to ./MARRMoT/Octave/optimoptions.m and disable this warning on lines 19-23 of the file.
# If you want to use MARRMoT's Matlab version, you must REMOVE the folder ./MARRMoT/Octave from your system. If you do not remove this folder, Matlab will not utilize its more powerful solver settings because it will preferentially navigate to the Octave folder and use those settings instead.
# ---
# ans =
#
#   scalar structure containing the fields:
#
#     Ea =  1.2674
#     Q =  22.569
#
# ans =  66
# ---
# You are currently using MARRMoT's Octave version.
# If this is intentional, please navigate to ./MARRMoT/Octave/optimoptions.m and disable this warning on lines 19-23 of the file.
# If you want to use MARRMoT's Matlab version, you must REMOVE the folder ./MARRMoT/Octave from your system. If you do not remove this folder, Matlab will not utilize its more powerful solver settings because it will preferentially navigate to the Octave folder and use those settings instead.
# ---
# ans =
#
#   scalar structure containing the fields:
#
#     Ea =  0.76041
#     Q = 0
#
# ans =  67
# ---
# You are currently using MARRMoT's Octave version.
# If this is intentional, please navigate to ./MARRMoT/Octave/optimoptions.m and disable this warning on lines 19-23 of the file.
# If you want to use MARRMoT's Matlab version, you must REMOVE the folder ./MARRMoT/Octave from your system. If you do not remove this folder, Matlab will not utilize its more powerful solver settings because it will preferentially navigate to the Octave folder and use those settings instead.
# ---
# ans =
#
#   scalar structure containing the fields:
#
#     Ea =  1.2335
#     Q = 0
#
# ans =  68
# ---
# You are currently using MARRMoT's Octave version.
# If this is intentional, please navigate to ./MARRMoT/Octave/optimoptions.m and disable this warning on lines 19-23 of the file.
# If you want to use MARRMoT's Matlab version, you must REMOVE the folder ./MARRMoT/Octave from your system. If you do not remove this folder, Matlab will not utilize its more powerful solver settings because it will preferentially navigate to the Octave folder and use those settings instead.
# ---
# ans =
#
#   scalar structure containing the fields:
#
#     Ea =  1.4456
#     Q = 0
#
# ans =  69
# ---
# You are currently using MARRMoT's Octave version.
# If this is intentional, please navigate to ./MARRMoT/Octave/optimoptions.m and disable this warning on lines 19-23 of the file.
# If you want to use MARRMoT's Matlab version, you must REMOVE the folder ./MARRMoT/Octave from your system. If you do not remove this folder, Matlab will not utilize its more powerful solver settings because it will preferentially navigate to the Octave folder and use those settings instead.
# ---
# ans =
#
#   scalar structure containing the fields:
#
#     Ea =  1.3642
#     Q = 0
#
# ans =  70
# ---
# You are currently using MARRMoT's Octave version.
# If this is intentional, please navigate to ./MARRMoT/Octave/optimoptions.m and disable this warning on lines 19-23 of the file.
# If you want to use MARRMoT's Matlab version, you must REMOVE the folder ./MARRMoT/Octave from your system. If you do not remove this folder, Matlab will not utilize its more powerful solver settings because it will preferentially navigate to the Octave folder and use those settings instead.
# ---
# ans =
#
#   scalar structure containing the fields:
#
#     Ea =  1.2183
#     Q = 0
#
# ans =  71
# ---
# You are currently using MARRMoT's Octave version.
# If this is intentional, please navigate to ./MARRMoT/Octave/optimoptions.m and disable this warning on lines 19-23 of the file.
# If you want to use MARRMoT's Matlab version, you must REMOVE the folder ./MARRMoT/Octave from your system. If you do not remove this folder, Matlab will not utilize its more powerful solver settings because it will preferentially navigate to the Octave folder and use those settings instead.
# ---
# ans =
#
#   scalar structure containing the fields:
#
#     Ea =  1.0402
#     Q = 0
#
# ans =  72
# ---
# You are currently using MARRMoT's Octave version.
# If this is intentional, please navigate to ./MARRMoT/Octave/optimoptions.m and disable this warning on lines 19-23 of the file.
# If you want to use MARRMoT's Matlab version, you must REMOVE the folder ./MARRMoT/Octave from your system. If you do not remove this folder, Matlab will not utilize its more powerful solver settings because it will preferentially navigate to the Octave folder and use those settings instead.
# ---
# ans =
#
#   scalar structure containing the fields:
#
#     Ea =  0.83665
#     Q = 0
#
# ans =  73
# ---
# You are currently using MARRMoT's Octave version.
# If this is intentional, please navigate to ./MARRMoT/Octave/optimoptions.m and disable this warning on lines 19-23 of the file.
# If you want to use MARRMoT's Matlab version, you must REMOVE the folder ./MARRMoT/Octave from your system. If you do not remove this folder, Matlab will not utilize its more powerful solver settings because it will preferentially navigate to the Octave folder and use those settings instead.
# ---
# ans =
#
#   scalar structure containing the fields:
#
#     Ea =  0.65935
#     Q = 0
#
# ans =  74
# ---
# You are currently using MARRMoT's Octave version.
# If this is intentional, please navigate to ./MARRMoT/Octave/optimoptions.m and disable this warning on lines 19-23 of the file.
# If you want to use MARRMoT's Matlab version, you must REMOVE the folder ./MARRMoT/Octave from your system. If you do not remove this folder, Matlab will not utilize its more powerful solver settings because it will preferentially navigate to the Octave folder and use those settings instead.
# ---
# ans =
#
#   scalar structure containing the fields:
#
#     Ea =  0.51143
#     Q = 0
#
# ans =  75
# ---
# You are currently using MARRMoT's Octave version.
# If this is intentional, please navigate to ./MARRMoT/Octave/optimoptions.m and disable this warning on lines 19-23 of the file.
# If you want to use MARRMoT's Matlab version, you must REMOVE the folder ./MARRMoT/Octave from your system. If you do not remove this folder, Matlab will not utilize its more powerful solver settings because it will preferentially navigate to the Octave folder and use those settings instead.
# ---
# ans =
#
#   scalar structure containing the fields:
#
#     Ea =  0.36056
#     Q = 0
#
# ans =  76
# ---
# You are currently using MARRMoT's Octave version.
# If this is intentional, please navigate to ./MARRMoT/Octave/optimoptions.m and disable this warning on lines 19-23 of the file.
# If you want to use MARRMoT's Matlab version, you must REMOVE the folder ./MARRMoT/Octave from your system. If you do not remove this folder, Matlab will not utilize its more powerful solver settings because it will preferentially navigate to the Octave folder and use those settings instead.
# ---
# ans =
#
#   scalar structure containing the fields:
#
#     Ea =  0.29764
#     Q = 0
#
# ans =  77
# ---
# You are currently using MARRMoT's Octave version.
# If this is intentional, please navigate to ./MARRMoT/Octave/optimoptions.m and disable this warning on lines 19-23 of the file.
# If you want to use MARRMoT's Matlab version, you must REMOVE the folder ./MARRMoT/Octave from your system. If you do not remove this folder, Matlab will not utilize its more powerful solver settings because it will preferentially navigate to the Octave folder and use those settings instead.
# ---
# ans =
#
#   scalar structure containing the fields:
#
#     Ea =  0.80959
#     Q = 0
#
# ans =  78
# ---
# You are currently using MARRMoT's Octave version.
# If this is intentional, please navigate to ./MARRMoT/Octave/optimoptions.m and disable this warning on lines 19-23 of the file.
# If you want to use MARRMoT's Matlab version, you must REMOVE the folder ./MARRMoT/Octave from your system. If you do not remove this folder, Matlab will not utilize its more powerful solver settings because it will preferentially navigate to the Octave folder and use those settings instead.
# ---
# ans =
#
#   scalar structure containing the fields:
#
#     Ea =  0.71417
#     Q = 0
#
# ans =  79
# ---
# You are currently using MARRMoT's Octave version.
# If this is intentional, please navigate to ./MARRMoT/Octave/optimoptions.m and disable this warning on lines 19-23 of the file.
# If you want to use MARRMoT's Matlab version, you must REMOVE the folder ./MARRMoT/Octave from your system. If you do not remove this folder, Matlab will not utilize its more powerful solver settings because it will preferentially navigate to the Octave folder and use those settings instead.
# ---
# ans =
#
#   scalar structure containing the fields:
#
#     Ea =  2.3225
#     Q =  3.9800
#
# ans =  80
# ---
# You are currently using MARRMoT's Octave version.
# If this is intentional, please navigate to ./MARRMoT/Octave/optimoptions.m and disable this warning on lines 19-23 of the file.
# If you want to use MARRMoT's Matlab version, you must REMOVE the folder ./MARRMoT/Octave from your system. If you do not remove this folder, Matlab will not utilize its more powerful solver settings because it will preferentially navigate to the Octave folder and use those settings instead.
# ---
# ans =
#
#   scalar structure containing the fields:
#
#     Ea =  2.5444
#     Q =  14.967
#
# ans =  81
# ---
# You are currently using MARRMoT's Octave version.
# If this is intentional, please navigate to ./MARRMoT/Octave/optimoptions.m and disable this warning on lines 19-23 of the file.
# If you want to use MARRMoT's Matlab version, you must REMOVE the folder ./MARRMoT/Octave from your system. If you do not remove this folder, Matlab will not utilize its more powerful solver settings because it will preferentially navigate to the Octave folder and use those settings instead.
# ---
# ans =
#
#   scalar structure containing the fields:
#
#     Ea =  1.5706
#     Q = 0
#
# ans =  82
# ---
# You are currently using MARRMoT's Octave version.
# If this is intentional, please navigate to ./MARRMoT/Octave/optimoptions.m and disable this warning on lines 19-23 of the file.
# If you want to use MARRMoT's Matlab version, you must REMOVE the folder ./MARRMoT/Octave from your system. If you do not remove this folder, Matlab will not utilize its more powerful solver settings because it will preferentially navigate to the Octave folder and use those settings instead.
# ---
# ans =
#
#   scalar structure containing the fields:
#
#     Ea =  1.5581
#     Q = 0
#
# ans =  83
# ---
# You are currently using MARRMoT's Octave version.
# If this is intentional, please navigate to ./MARRMoT/Octave/optimoptions.m and disable this warning on lines 19-23 of the file.
# If you want to use MARRMoT's Matlab version, you must REMOVE the folder ./MARRMoT/Octave from your system. If you do not remove this folder, Matlab will not utilize its more powerful solver settings because it will preferentially navigate to the Octave folder and use those settings instead.
# ---
# ans =
#
#   scalar structure containing the fields:
#
#     Ea =  1.3049
#     Q =    1.2710e-14
#
# ans =  84
# ---
# You are currently using MARRMoT's Octave version.
# If this is intentional, please navigate to ./MARRMoT/Octave/optimoptions.m and disable this warning on lines 19-23 of the file.
# If you want to use MARRMoT's Matlab version, you must REMOVE the folder ./MARRMoT/Octave from your system. If you do not remove this folder, Matlab will not utilize its more powerful solver settings because it will preferentially navigate to the Octave folder and use those settings instead.
# ---
# ans =
#
#   scalar structure containing the fields:
#
#     Ea =  1.5676
#     Q = 0
#
# ans =  85
# ---
# You are currently using MARRMoT's Octave version.
# If this is intentional, please navigate to ./MARRMoT/Octave/optimoptions.m and disable this warning on lines 19-23 of the file.
# ...
#     Q =  22.198
#
# ans =  328
# ---
# You are currently using MARRMoT's Octave version.
# If this is intentional, please navigate to ./MARRMoT/Octave/optimoptions.m and disable this warning on lines 19-23 of the file.
# If you want to use MARRMoT's Matlab version, you must REMOVE the folder ./MARRMoT/Octave from your system. If you do not remove this folder, Matlab will not utilize its more powerful solver settings because it will preferentially navigate to the Octave folder and use those settings instead.
# ---
# ans =
#
#   scalar structure containing the fields:
#
#     Ea =  0.64358
#     Q = 0
#
# ans =  329
# ---
# You are currently using MARRMoT's Octave version.
# If this is intentional, please navigate to ./MARRMoT/Octave/optimoptions.m and disable this warning on lines 19-23 of the file.
# If you want to use MARRMoT's Matlab version, you must REMOVE the folder ./MARRMoT/Octave from your system. If you do not remove this folder, Matlab will not utilize its more powerful solver settings because it will preferentially navigate to the Octave folder and use those settings instead.
# ---
# ans =
#
#   scalar structure containing the fields:
#
#     Ea =  0.70161
#     Q = 0
#
# ans =  330
# ---
# You are currently using MARRMoT's Octave version.
# If this is intentional, please navigate to ./MARRMoT/Octave/optimoptions.m and disable this warning on lines 19-23 of the file.
# If you want to use MARRMoT's Matlab version, you must REMOVE the folder ./MARRMoT/Octave from your system. If you do not remove this folder, Matlab will not utilize its more powerful solver settings because it will preferentially navigate to the Octave folder and use those settings instead.
# ---
# ans =
#
#   scalar structure containing the fields:
#
#     Ea =  0.77193
#     Q = 0
#
# ans =  331
# ---
# You are currently using MARRMoT's Octave version.
# If this is intentional, please navigate to ./MARRMoT/Octave/optimoptions.m and disable this warning on lines 19-23 of the file.
# If you want to use MARRMoT's Matlab version, you must REMOVE the folder ./MARRMoT/Octave from your system. If you do not remove this folder, Matlab will not utilize its more powerful solver settings because it will preferentially navigate to the Octave folder and use those settings instead.
# ---
# ans =
#
#   scalar structure containing the fields:
#
#     Ea =  0.87758
#     Q =  0.00000073116
#
# ans =  332
# ---
# You are currently using MARRMoT's Octave version.
# If this is intentional, please navigate to ./MARRMoT/Octave/optimoptions.m and disable this warning on lines 19-23 of the file.
# If you want to use MARRMoT's Matlab version, you must REMOVE the folder ./MARRMoT/Octave from your system. If you do not remove this folder, Matlab will not utilize its more powerful solver settings because it will preferentially navigate to the Octave folder and use those settings instead.
# ---
# ans =
#
#   scalar structure containing the fields:
#
#     Ea =  0.80812
#     Q = 0
#
# ans =  333
# ---
# You are currently using MARRMoT's Octave version.
# If this is intentional, please navigate to ./MARRMoT/Octave/optimoptions.m and disable this warning on lines 19-23 of the file.
# If you want to use MARRMoT's Matlab version, you must REMOVE the folder ./MARRMoT/Octave from your system. If you do not remove this folder, Matlab will not utilize its more powerful solver settings because it will preferentially navigate to the Octave folder and use those settings instead.
# ---
# ans =
#
#   scalar structure containing the fields:
#
#     Ea =  0.49934
#     Q = 0
#
# ans =  334
# ---
# You are currently using MARRMoT's Octave version.
# If this is intentional, please navigate to ./MARRMoT/Octave/optimoptions.m and disable this warning on lines 19-23 of the file.
# If you want to use MARRMoT's Matlab version, you must REMOVE the folder ./MARRMoT/Octave from your system. If you do not remove this folder, Matlab will not utilize its more powerful solver settings because it will preferentially navigate to the Octave folder and use those settings instead.
# ---
# ans =
#
#   scalar structure containing the fields:
#
#     Ea =  0.43519
#     Q = 0
#
# ans =  335
# ---
# You are currently using MARRMoT's Octave version.
# If this is intentional, please navigate to ./MARRMoT/Octave/optimoptions.m and disable this warning on lines 19-23 of the file.
# If you want to use MARRMoT's Matlab version, you must REMOVE the folder ./MARRMoT/Octave from your system. If you do not remove this folder, Matlab will not utilize its more powerful solver settings because it will preferentially navigate to the Octave folder and use those settings instead.
# ---
# ans =
#
#   scalar structure containing the fields:
#
#     Ea =  0.44094
#     Q = 0
#
# ans =  336
# ---
# You are currently using MARRMoT's Octave version.
# If this is intentional, please navigate to ./MARRMoT/Octave/optimoptions.m and disable this warning on lines 19-23 of the file.
# If you want to use MARRMoT's Matlab version, you must REMOVE the folder ./MARRMoT/Octave from your system. If you do not remove this folder, Matlab will not utilize its more powerful solver settings because it will preferentially navigate to the Octave folder and use those settings instead.
# ---
# ans =
#
#   scalar structure containing the fields:
#
#     Ea =  0.42131
#     Q = 0
#
# ans =  337
# ---
# You are currently using MARRMoT's Octave version.
# If this is intentional, please navigate to ./MARRMoT/Octave/optimoptions.m and disable this warning on lines 19-23 of the file.
# If you want to use MARRMoT's Matlab version, you must REMOVE the folder ./MARRMoT/Octave from your system. If you do not remove this folder, Matlab will not utilize its more powerful solver settings because it will preferentially navigate to the Octave folder and use those settings instead.
# ---
# ans =
#
#   scalar structure containing the fields:
#
#     Ea =  0.35349
#     Q = 0
#
# ans =  338
# ---
# You are currently using MARRMoT's Octave version.
# If this is intentional, please navigate to ./MARRMoT/Octave/optimoptions.m and disable this warning on lines 19-23 of the file.
# If you want to use MARRMoT's Matlab version, you must REMOVE the folder ./MARRMoT/Octave from your system. If you do not remove this folder, Matlab will not utilize its more powerful solver settings because it will preferentially navigate to the Octave folder and use those settings instead.
# ---
# ans =
#
#   scalar structure containing the fields:
#
#     Ea =  0.30279
#     Q = 0
#
# ans =  339
# ---
# You are currently using MARRMoT's Octave version.
# If this is intentional, please navigate to ./MARRMoT/Octave/optimoptions.m and disable this warning on lines 19-23 of the file.
# If you want to use MARRMoT's Matlab version, you must REMOVE the folder ./MARRMoT/Octave from your system. If you do not remove this folder, Matlab will not utilize its more powerful solver settings because it will preferentially navigate to the Octave folder and use those settings instead.
# ---
# ans =
#
#   scalar structure containing the fields:
#
#     Ea =  0.34554
#     Q = 0
#
# ans =  340
# ---
# You are currently using MARRMoT's Octave version.
# If this is intentional, please navigate to ./MARRMoT/Octave/optimoptions.m and disable this warning on lines 19-23 of the file.
# If you want to use MARRMoT's Matlab version, you must REMOVE the folder ./MARRMoT/Octave from your system. If you do not remove this folder, Matlab will not utilize its more powerful solver settings because it will preferentially navigate to the Octave folder and use those settings instead.
# ---
# ans =
#
#   scalar structure containing the fields:
#
#     Ea =  0.40636
#     Q = 0
#
# ans =  341
# ---
# You are currently using MARRMoT's Octave version.
# If this is intentional, please navigate to ./MARRMoT/Octave/optimoptions.m and disable this warning on lines 19-23 of the file.
# If you want to use MARRMoT's Matlab version, you must REMOVE the folder ./MARRMoT/Octave from your system. If you do not remove this folder, Matlab will not utilize its more powerful solver settings because it will preferentially navigate to the Octave folder and use those settings instead.
# ---
# ans =
#
#   scalar structure containing the fields:
#
#     Ea =  0.34086
#     Q = 0
#
# ans =  342
# ---
# You are currently using MARRMoT's Octave version.
# If this is intentional, please navigate to ./MARRMoT/Octave/optimoptions.m and disable this warning on lines 19-23 of the file.
# If you want to use MARRMoT's Matlab version, you must REMOVE the folder ./MARRMoT/Octave from your system. If you do not remove this folder, Matlab will not utilize its more powerful solver settings because it will preferentially navigate to the Octave folder and use those settings instead.
# ---
# ans =
#
#   scalar structure containing the fields:
#
#     Ea =  0.57085
#     Q =  1.7953
#
# ans =  343
# ---
# You are currently using MARRMoT's Octave version.
# If this is intentional, please navigate to ./MARRMoT/Octave/optimoptions.m and disable this warning on lines 19-23 of the file.
# If you want to use MARRMoT's Matlab version, you must REMOVE the folder ./MARRMoT/Octave from your system. If you do not remove this folder, Matlab will not utilize its more powerful solver settings because it will preferentially navigate to the Octave folder and use those settings instead.
# ---
# ans =
#
#   scalar structure containing the fields:
#
#     Ea =  0.49770
#     Q =  8.4187
#
# ans =  344
# ---
# You are currently using MARRMoT's Octave version.
# If this is intentional, please navigate to ./MARRMoT/Octave/optimoptions.m and disable this warning on lines 19-23 of the file.
# If you want to use MARRMoT's Matlab version, you must REMOVE the folder ./MARRMoT/Octave from your system. If you do not remove this folder, Matlab will not utilize its more powerful solver settings because it will preferentially navigate to the Octave folder and use those settings instead.
# ---
# ans =
#
#   scalar structure containing the fields:
#
#     Ea =  0.50043
#     Q = 0
#
# ans =  345
# ---
# You are currently using MARRMoT's Octave version.
# If this is intentional, please navigate to ./MARRMoT/Octave/optimoptions.m and disable this warning on lines 19-23 of the file.
# If you want to use MARRMoT's Matlab version, you must REMOVE the folder ./MARRMoT/Octave from your system. If you do not remove this folder, Matlab will not utilize its more powerful solver settings because it will preferentially navigate to the Octave folder and use those settings instead.
# ---
# ans =
#
#   scalar structure containing the fields:
#
#     Ea =  0.60026
#     Q =  0.10007
#
# ans =  346
# ---
# You are currently using MARRMoT's Octave version.
# If this is intentional, please navigate to ./MARRMoT/Octave/optimoptions.m and disable this warning on lines 19-23 of the file.
# If you want to use MARRMoT's Matlab version, you must REMOVE the folder ./MARRMoT/Octave from your system. If you do not remove this folder, Matlab will not utilize its more powerful solver settings because it will preferentially navigate to the Octave folder and use those settings instead.
# ---
# ans =
#
#   scalar structure containing the fields:
#
#     Ea =  0.56876
#     Q =  3.1237
#
# ans =  347
# ---
# You are currently using MARRMoT's Octave version.
# If this is intentional, please navigate to ./MARRMoT/Octave/optimoptions.m and disable this warning on lines 19-23 of the file.
# If you want to use MARRMoT's Matlab version, you must REMOVE the folder ./MARRMoT/Octave from your system. If you do not remove this folder, Matlab will not utilize its more powerful solver settings because it will preferentially navigate to the Octave folder and use those settings instead.
# ---
# ans =
#
#   scalar structure containing the fields:
#
#     Ea =  0.43043
#     Q = 0
#
# ans =  348
# ---
# You are currently using MARRMoT's Octave version.
# If this is intentional, please navigate to ./MARRMoT/Octave/optimoptions.m and disable this warning on lines 19-23 of the file.
# If you want to use MARRMoT's Matlab version, you must REMOVE the folder ./MARRMoT/Octave from your system. If you do not remove this folder, Matlab will not utilize its more powerful solver settings because it will preferentially navigate to the Octave folder and use those settings instead.
# ---
# ans =
#
#   scalar structure containing the fields:
#
#     Ea =  0.44884
#     Q = 0
#
# ans =  349
# ---
# You are currently using MARRMoT's Octave version.
# If this is intentional, please navigate to ./MARRMoT/Octave/optimoptions.m and disable this warning on lines 19-23 of the file.
# If you want to use MARRMoT's Matlab version, you must REMOVE the folder ./MARRMoT/Octave from your system. If you do not remove this folder, Matlab will not utilize its more powerful solver settings because it will preferentially navigate to the Octave folder and use those settings instead.
# ---
# ans =
#
#   scalar structure containing the fields:
#
#     Ea =  0.46323
#     Q = 0
#
# ans =  350
# ---
# You are currently using MARRMoT's Octave version.
# If this is intentional, please navigate to ./MARRMoT/Octave/optimoptions.m and disable this warning on lines 19-23 of the file.
# If you want to use MARRMoT's Matlab version, you must REMOVE the folder ./MARRMoT/Octave from your system. If you do not remove this folder, Matlab will not utilize its more powerful solver settings because it will preferentially navigate to the Octave folder and use those settings instead.
# ---
# ans =
#
#   scalar structure containing the fields:
#
#     Ea =  0.32511
#     Q = 0
#
# ans =  351
# ---
# You are currently using MARRMoT's Octave version.
# If this is intentional, please navigate to ./MARRMoT/Octave/optimoptions.m and disable this warning on lines 19-23 of the file.
# If you want to use MARRMoT's Matlab version, you must REMOVE the folder ./MARRMoT/Octave from your system. If you do not remove this folder, Matlab will not utilize its more powerful solver settings because it will preferentially navigate to the Octave folder and use those settings instead.
# ---
# ans =
#
#   scalar structure containing the fields:
#
#     Ea =  0.31514
#     Q =  0.000000000095395
#
# ans =  352
# ---
# You are currently using MARRMoT's Octave version.
# If this is intentional, please navigate to ./MARRMoT/Octave/optimoptions.m and disable this warning on lines 19-23 of the file.
# If you want to use MARRMoT's Matlab version, you must REMOVE the folder ./MARRMoT/Octave from your system. If you do not remove this folder, Matlab will not utilize its more powerful solver settings because it will preferentially navigate to the Octave folder and use those settings instead.
# ---
# ans =
#
#   scalar structure containing the fields:
#
#     Ea =  0.35883
#     Q = 0
#
# ans =  353
# ---
# You are currently using MARRMoT's Octave version.
# If this is intentional, please navigate to ./MARRMoT/Octave/optimoptions.m and disable this warning on lines 19-23 of the file.
# If you want to use MARRMoT's Matlab version, you must REMOVE the folder ./MARRMoT/Octave from your system. If you do not remove this folder, Matlab will not utilize its more powerful solver settings because it will preferentially navigate to the Octave folder and use those settings instead.
# ---
# ans =
#
#   scalar structure containing the fields:
#
#     Ea =  0.47748
#     Q =  6.1469
#
# ans =  354
# ---
# You are currently using MARRMoT's Octave version.
# If this is intentional, please navigate to ./MARRMoT/Octave/optimoptions.m and disable this warning on lines 19-23 of the file.
# If you want to use MARRMoT's Matlab version, you must REMOVE the folder ./MARRMoT/Octave from your system. If you do not remove this folder, Matlab will not utilize its more powerful solver settings because it will preferentially navigate to the Octave folder and use those settings instead.
# ---
# ans =
#
#   scalar structure containing the fields:
#
#     Ea =  0.41916
#     Q = 0
#
# ans =  355
# ---
# You are currently using MARRMoT's Octave version.
# If this is intentional, please navigate to ./MARRMoT/Octave/optimoptions.m and disable this warning on lines 19-23 of the file.
# If you want to use MARRMoT's Matlab version, you must REMOVE the folder ./MARRMoT/Octave from your system. If you do not remove this folder, Matlab will not utilize its more powerful solver settings because it will preferentially navigate to the Octave folder and use those settings instead.
# ---
# ans =
#
#   scalar structure containing the fields:
#
#     Ea =  0.37623
#     Q = 0
#
# ans =  356

# %%
plt.plot(discharge)
plt.show()

# %%
# %matplotlib inline  
import os

import cftime
import hydrostats.visual as hv
import numpy.ma as ma
import pandas as pd
import xarray as xr

from ewatercycle.parametersetdb import build_from_urls
from ewatercycle.observation.grdc import get_grdc_data
from grpc4bmi.bmi_client_docker import BmiClientDocker
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-8-2bfc982b7496> in <module>
#       8 import xarray as xr
#       9
# ---> 10 from ewatercycle.parametersetdb import build_from_urls
#      11 from ewatercycle.observation.grdc import get_grdc_data
#      12 from grpc4bmi.bmi_client_docker import BmiClientDocker
#
# ModuleNotFoundError: No module named 'ewatercycle'

# %%
import datetime

tstart = model.get_start_time()
ts_str = cftime.datetime(tstart[0,0], tstart[0,1], tstart[0,2]).strftime()
dstart = ts_str.split()[0]



tend = model.get_end_time()
te_str = cftime.datetime(tend[0,0], tend[0,1], tend[0,2]).strftime()
dend = te_str.split()[0]
# Out:
# ans =
#
#    1989      1      1      0      0      0
#
# ans =
#
#    1992     12     31      0      0      0

# %%
tstep = int(model.get_time_step())
tunit = model.get_time_units()
tstep_nmbr = (tend - tstart) / tstep
# Out:
# ans =  1
# ans = day

# %%
variable = 'discharge'
pixel_index = np.array([8481])
variable_overtime = []

# %%
while model.get_current_time() < tend:
    model.update()
    value_at_pixel = model.get_value_at_indices(variable, pixel_index)[0]
    variable_overtime.append((model.get_current_time(), value_at_pixel))
# Out:
# ans =  356
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-b66b443ed3dd> in <module>
# ----> 1 while model.get_current_time() < tend:
#       2     model.update()
#       3     value_at_pixel = model.get_value_at_indices(variable, pixel_index)[0]
#       4     variable_overtime.append((model.get_current_time(), value_at_pixel))
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
